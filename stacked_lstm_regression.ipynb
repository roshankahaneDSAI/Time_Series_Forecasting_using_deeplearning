# %% [markdown]
# # Stacked LSTM regression

# %%
# Suppress warnings 
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
tf.random.set_seed(0)
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import LSTM, Dense, Activation, Dropout
from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers, backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# WARNING:tensorflow:From c:\poetry-venvs\retail-demand-forecasting-aILZzb17-py3.10\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
TRAIN_RANGE = (datetime(1949, 1, 1), datetime(1956, 12, 1))
VALID_RANGE = (datetime(1957, 1, 1), datetime(1958, 12, 1))
TEST_RANGE = (datetime(1959, 1, 1), datetime(1960, 12, 1))
TIMESTEPS = 12  # Input 12 months to predict next month

# %% [markdown]
# ## 1. Read in dataset

# %%
data = pd.read_csv('data/airline-passengers.csv')
data.index = pd.to_datetime(data.Month)  # Set datetime index
data.drop(['Month'], axis=1, inplace=True)

# %%
data.plot(figsize=(14, 8), title='Monthly airline passengers')
# Out:
# <Axes: title={'center': 'Monthly airline passengers'}, xlabel='Month'>

# %% [markdown]
# ## 2.1 Normalize dataset

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data['NormalizedPassengers'] = scaler.fit_transform(data['Passengers'].values.reshape(-1, 1)).flatten()
data[['NormalizedPassengers']].plot(figsize=(14, 8), title='Monthly normalized airline passengers')
# Out:
# <Axes: title={'center': 'Monthly normalized airline passengers'}, xlabel='Month'>

# %% [markdown]
# ## 2.2 Preprocess dataset

# %%
def create_dataset(data, timesteps=TIMESTEPS):
    """Create input and output pairs for training lstm.
    Params:
        data (pandas.DataFrame): Normalized dataset
        timesteps (int, default: TIMESTEPS): Input time length 
    Returns:
        X (numpy.array): Input for lstm
        y (numpy.array): Output for lstm
        y_date (list): Datetime of output
        start_values (list): Start valeus of each input
    """
    X, y, y_date, start_values = [], [], [], []
    
    for i in range(len(data) - timesteps):
        Xt = data.iloc[i:i+timesteps].values
        yt = data.iloc[i+timesteps]
        yt_date = data.index[i+timesteps].to_pydatetime()
        
        # Subtract a start value from each values in the timestep.
        start_value = Xt[0]
        Xt = Xt - start_value
        yt = yt - start_value
        
        X.append(Xt)
        y.append(yt)
        y_date.append(yt_date)
        start_values.append(start_value)
        
    return np.array(X), np.array(y), y_date, start_values

# %%
def split_train_valid_test(X, y, y_date, train_range=TRAIN_RANGE, valid_range=VALID_RANGE, test_range=TEST_RANGE):
    """Split X and y into train, valid, and test periods.
    Params:
        X (numpy.array): Input for lstm
        y (numpy.array): Output for lstm
        y_date (list): Datetime of output
        train_range (tuple): Train period
        valid_range (tuple): Validation period
        test_range (tuple): Test period
    Returns:
        X_train (pandas.DataFrame)
        X_valid (pandas.DataFrame)
        X_test (pandas.DataFrame)
        y_train (pandas.DataFrame)
        y_valid (pandas.DataFrame)
        y_test (pandas.DataFrame)
        y_date_train (list)
        y_date_valid (list)
        y_date_test (list)
    """
    train_end_idx = y_date.index(train_range[1])
    valid_end_idx = y_date.index(valid_range[1])
    
    X_train = X[:train_end_idx+1, :]
    X_valid = X[train_end_idx+1:valid_end_idx+1, :]
    X_test = X[valid_end_idx+1:, :]
    
    y_train = y[:train_end_idx+1]
    y_valid = y[train_end_idx+1:valid_end_idx+1]
    y_test = y[valid_end_idx+1:]
    
    y_date_train = y_date[:train_end_idx+1]
    y_date_valid = y_date[train_end_idx+1:valid_end_idx+1]
    y_date_test = y_date[valid_end_idx+1:]
    
    return X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test

# %%
# Create input and output pairs for training lstm.
X, y, y_date, start_values = create_dataset(data[['NormalizedPassengers']])

# Split X and y into train, valid, and test periods.
X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test = split_train_valid_test(X, y, y_date)

# %%
print(X_train.shape, X_valid.shape, X_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (84, 12, 1) (24, 12, 1) (24, 12, 1)
# (84, 1) (24, 1) (24, 1)

# %% [markdown]
# ## 3. Create stacked LSTM regression model

# %%
def create_model(timesteps=TIMESTEPS):
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape=(timesteps, 1), name='lstm_1'))  # Input timesteps months with scalar value.
    model.add(LSTM(32, name='lstm_2'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizers.Adam(lr=0.01), metrics=['mean_absolute_error'])
    return model

# %%
# Create model
model = create_model()
model.summary()
# Out:
# WARNING:tensorflow:From c:\poetry-venvs\retail-demand-forecasting-aILZzb17-py3.10\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 12, 128)           66560
#
#  lstm_2 (LSTM)               (None, 32)                20608
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 87201 (340.63 KB)
# Trainable params: 87201 (340.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks of training.
es = EarlyStopping(monitor='val_mean_absolute_error', min_delta=0, patience=15, verbose=1, mode='auto')
fn = 'trained_model.h5'
mc = ModelCheckpoint(filepath=fn, save_best_only=True)
callbacks = [es, mc]

# %%
# Start training model.
fit = model.fit(
    X_train, y_train, 
    batch_size=32,
    epochs=1000, 
    verbose=2,
    validation_data=(X_valid, y_valid), 
    callbacks=callbacks)
# Out:
# Epoch 1/1000
# WARNING:tensorflow:From c:\poetry-venvs\retail-demand-forecasting-aILZzb17-py3.10\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\poetry-venvs\retail-demand-forecasting-aILZzb17-py3.10\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\poetry-venvs\retail-demand-forecasting-aILZzb17-py3.10\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\poetry-venvs\retail-demand-forecasting-aILZzb17-py3.10\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 3/3 - 4s - loss: 0.0026 - mean_absolute_error: 0.0433 - val_loss: 0.0025 - val_mean_absolute_error: 0.0427 - 4s/epoch - 1s/step
# Epoch 2/1000
# 3/3 - 0s - loss: 0.0014 - mean_absolute_error: 0.0312 - val_loss: 0.0021 - val_mean_absolute_error: 0.0383 - 55ms/epoch - 18ms/step
# Epoch 3/1000
# 3/3 - 0s - loss: 0.0011 - mean_absolute_error: 0.0275 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283 - 57ms/epoch - 19ms/step
# Epoch 4/1000
# 3/3 - 0s - loss: 9.6517e-04 - mean_absolute_error: 0.0250 - val_loss: 0.0011 - val_mean_absolute_error: 0.0296 - 53ms/epoch - 18ms/step
# Epoch 5/1000
# 3/3 - 0s - loss: 0.0011 - mean_absolute_error: 0.0267 - val_loss: 0.0010 - val_mean_absolute_error: 0.0290 - 55ms/epoch - 18ms/step
# Epoch 6/1000
# 3/3 - 0s - loss: 9.4360e-04 - mean_absolute_error: 0.0253 - val_loss: 0.0010 - val_mean_absolute_error: 0.0279 - 53ms/epoch - 18ms/step
# Epoch 7/1000
# 3/3 - 0s - loss: 8.9843e-04 - mean_absolute_error: 0.0245 - val_loss: 0.0011 - val_mean_absolute_error: 0.0276 - 43ms/epoch - 14ms/step
# Epoch 8/1000
# 3/3 - 0s - loss: 9.2540e-04 - mean_absolute_error: 0.0250 - val_loss: 0.0011 - val_mean_absolute_error: 0.0274 - 42ms/epoch - 14ms/step
# Epoch 9/1000
# 3/3 - 0s - loss: 8.8739e-04 - mean_absolute_error: 0.0242 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279 - 39ms/epoch - 13ms/step
# Epoch 10/1000
# 3/3 - 0s - loss: 8.8319e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0012 - val_mean_absolute_error: 0.0283 - 41ms/epoch - 14ms/step
# Epoch 11/1000
# 3/3 - 0s - loss: 8.8676e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280 - 38ms/epoch - 13ms/step
# Epoch 12/1000
# 3/3 - 0s - loss: 8.8228e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275 - 39ms/epoch - 13ms/step
# Epoch 13/1000
# 3/3 - 0s - loss: 8.6181e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0271 - 41ms/epoch - 14ms/step
# Epoch 14/1000
# 3/3 - 0s - loss: 8.5886e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0010 - val_mean_absolute_error: 0.0266 - 38ms/epoch - 13ms/step
# Epoch 15/1000
# 3/3 - 0s - loss: 8.6736e-04 - mean_absolute_error: 0.0239 - val_loss: 0.0010 - val_mean_absolute_error: 0.0266 - 40ms/epoch - 13ms/step
# Epoch 16/1000
# 3/3 - 0s - loss: 8.6349e-04 - mean_absolute_error: 0.0239 - val_loss: 9.9449e-04 - val_mean_absolute_error: 0.0269 - 56ms/epoch - 19ms/step
# Epoch 17/1000
# 3/3 - 0s - loss: 8.5508e-04 - mean_absolute_error: 0.0237 - val_loss: 9.9306e-04 - val_mean_absolute_error: 0.0268 - 58ms/epoch - 19ms/step
# Epoch 18/1000
# 3/3 - 0s - loss: 8.5482e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0010 - val_mean_absolute_error: 0.0266 - 50ms/epoch - 17ms/step
# Epoch 19/1000
# 3/3 - 0s - loss: 8.4916e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263 - 53ms/epoch - 18ms/step
# Epoch 20/1000
# 3/3 - 0s - loss: 8.4888e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264 - 51ms/epoch - 17ms/step
# Epoch 21/1000
# 3/3 - 0s - loss: 8.8202e-04 - mean_absolute_error: 0.0244 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267 - 51ms/epoch - 17ms/step
# Epoch 22/1000
# 3/3 - 0s - loss: 8.5803e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267 - 48ms/epoch - 16ms/step
# Epoch 23/1000
# 3/3 - 0s - loss: 8.5855e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265 - 41ms/epoch - 14ms/step
# Epoch 24/1000
# 3/3 - 0s - loss: 8.6738e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - 39ms/epoch - 13ms/step
# Epoch 25/1000
# 3/3 - 0s - loss: 8.4170e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0010 - val_mean_absolute_error: 0.0260 - 38ms/epoch - 13ms/step
# Epoch 26/1000
# 3/3 - 0s - loss: 8.3352e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0010 - val_mean_absolute_error: 0.0262 - 39ms/epoch - 13ms/step
# Epoch 27/1000
# 3/3 - 0s - loss: 8.3692e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263 - 45ms/epoch - 15ms/step
# Epoch 28/1000
# 3/3 - 0s - loss: 8.3677e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0010 - val_mean_absolute_error: 0.0261 - 49ms/epoch - 16ms/step
# Epoch 29/1000
# 3/3 - 0s - loss: 8.3576e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256 - 48ms/epoch - 16ms/step
# Epoch 30/1000
# 3/3 - 0s - loss: 8.3484e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256 - 45ms/epoch - 15ms/step
# Epoch 31/1000
# 3/3 - 0s - loss: 8.3262e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256 - 47ms/epoch - 16ms/step
# Epoch 32/1000
# 3/3 - 0s - loss: 8.3123e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - 48ms/epoch - 16ms/step
# Epoch 33/1000
# 3/3 - 0s - loss: 8.3442e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0010 - val_mean_absolute_error: 0.0261 - 43ms/epoch - 14ms/step
# Epoch 34/1000
# 3/3 - 0s - loss: 8.2925e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - 40ms/epoch - 13ms/step
# Epoch 35/1000
# 3/3 - 0s - loss: 8.3192e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - 43ms/epoch - 14ms/step
# Epoch 36/1000
# 3/3 - 0s - loss: 8.4004e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - 42ms/epoch - 14ms/step
# Epoch 37/1000
# 3/3 - 0s - loss: 8.2627e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - 45ms/epoch - 15ms/step
# Epoch 38/1000
# 3/3 - 0s - loss: 8.2226e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258 - 47ms/epoch - 16ms/step
# Epoch 39/1000
# 3/3 - 0s - loss: 8.2087e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259 - 43ms/epoch - 14ms/step
# Epoch 40/1000
# 3/3 - 0s - loss: 8.2959e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258 - 44ms/epoch - 15ms/step
# Epoch 41/1000
# 3/3 - 0s - loss: 8.1826e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258 - 46ms/epoch - 15ms/step
# Epoch 42/1000
# 3/3 - 0s - loss: 8.4642e-04 - mean_absolute_error: 0.0240 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258 - 47ms/epoch - 16ms/step
# Epoch 43/1000
# 3/3 - 0s - loss: 8.1200e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261 - 45ms/epoch - 15ms/step
# Epoch 44/1000
# 3/3 - 0s - loss: 8.6614e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266 - 47ms/epoch - 16ms/step
# Epoch 44: early stopping

# %%
# Plot training history
fig, (axL, axR) = plt.subplots(ncols=2, figsize=(10, 4))
axL.plot(fit.history['loss'], label="loss (mse) for training")
axL.plot(fit.history['val_loss'], label="loss (mse) for validation")
axL.set_title('model loss')
axL.set_xlabel('epoch')
axL.set_ylabel('loss')
axL.legend(loc='upper right')

axR.plot(fit.history['mean_absolute_error'], label="mae for training")
axR.plot(fit.history['val_mean_absolute_error'], label="mae for validation")
axR.set_title('model mse')
axR.set_xlabel('epoch')
axR.set_ylabel('mse')
axR.legend(loc='upper right')

plt.show()

# Load best model
model = load_model(fn)

# %%
def evaluate_model(data, scaler, X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test, start_values, model):
    """Evaluate trained model by rmse (root mean squared error) and mae (mean absolute error)'"""
    
    # Predict next month passengers
    pred_train = model.predict(X_train)
    pred_valid = model.predict(X_valid)
    pred_test = model.predict(X_test)
    
    # Add start_values that were subtracted when preprocessing.
    pred_train  = pred_train + start_values[:len(X_train)]
    pred_valid  = pred_valid + start_values[len(X_train):len(X_train)+len(X_valid)]
    pred_test  = pred_test + start_values[len(X_train)+len(X_valid):]
    
    # Inverse transform normalization
    pred_train = scaler.inverse_transform(pred_train).flatten()
    pred_valid = scaler.inverse_transform(pred_valid).flatten()
    pred_test = scaler.inverse_transform(pred_test).flatten()
    
    pred_df = data.copy()
    pred_df.loc[y_date_train[0]:y_date_train[-1], 'PredictionTrain'] = pred_train
    pred_df.loc[y_date_valid[0]:y_date_valid[-1], 'PredictionValid'] = pred_valid
    pred_df.loc[y_date_test[0]:y_date_test[-1], 'PredictionTest'] = pred_test
    pred_df[['Passengers', 'PredictionTrain', 'PredictionValid', 'PredictionTest']].plot(figsize=(12, 6), title='Predicted monthly airline passengers')
    fig.show()
    
    # Add start_values that were subtracted when preprocessing.
    y_train  = y_train + start_values[:len(X_train)]
    y_valid  = y_valid + start_values[len(X_train):len(X_train)+len(X_valid)]
    y_test  = y_test + start_values[len(X_train)+len(X_valid):]
    
    # Inverse transform normalization
    y_train = scaler.inverse_transform(y_train).flatten()
    y_valid = scaler.inverse_transform(y_valid).flatten()
    y_test = scaler.inverse_transform(y_test).flatten()
    
    # Evaluate prediction scores of model.
    for y, pred, mode in zip([y_train, y_valid, y_test], [pred_train, pred_valid, pred_test], ['train', 'valid', 'test']):
        rmse = np.sqrt(mean_squared_error(y, pred))
        mae = mean_absolute_error(y, pred)
        print(f'{mode} rmse: {rmse:.06f}, mae: {mae:.06f}')

# %%
evaluate_model(data, scaler, X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test, start_values, model)
# Out:
# 3/3 [==============================] - 1s 5ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# train rmse: 15.142386, mae: 12.234550
# valid rmse: 16.323671, mae: 13.882739
# test rmse: 24.388909, mae: 20.380524
